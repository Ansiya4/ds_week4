# %%
import pandas as pd
import numpy as np

# %%
s1=pd.Series(['anu','manu','sinu'])
s1
# Out:
# 0     anu
# 1    manu
# 2    sinu
# dtype: object

# %%
s2 = pd.Series(np.random.randn(3),index=['a','b','c'])
s2
# Out:
# a    0.289309
# b    0.769061
# c   -1.450895
# dtype: float64

# %%
d={
    'a':1,
    'b':2,
    'c':3
}
s3 = pd.Series(d)
s3
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
s4 = pd.Series(d,index=['a','b','f'])
s4
# Out:
# a    1.0
# b    2.0
# f    NaN
# dtype: float64

# %%
s5 = pd.Series(10,index=['a','b','f'])
s5
# Out:
# a    10
# b    10
# f    10
# dtype: int64

# %%
d = {
    'Name': ['anu','manu','sinu'],
    'Age':[12,13,14],
    'Place':['cochi','calicut','banglure']
    }
df1= pd.DataFrame(d)
df1
# Out:
#    Name  Age     Place
# 0   anu   12     cochi
# 1  manu   13   calicut
# 2  sinu   14  banglure

# %%
df1=pd.DataFrame(d,index=['s1','s2','s3'])
df1
# Out:
#     Name  Age     Place
# s1   anu   12     cochi
# s2  manu   13   calicut
# s3  sinu   14  banglure

# %%
df1.columns
# Out:
# Index(['Name', 'Age', 'City'], dtype='object')

# %%
df1.columns=['Name', 'Age', 'Place']

# %%
df1
# Out:
#     Name  City       Age
# s1   anu    12     cochi
# s2  manu    13   calicut
# s3  sinu    14  banglure

# %%
df1.Name
# Out:
# s1     anu
# s2    manu
# s3    sinu
# Name: Name, dtype: object

# %%
type(df1.Name)
# Out:
# pandas.core.series.Series

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
d2 = [{'a':1,'b':2},
      {'a':3,'b':4}]
df3 = pd.DataFrame(d2)

# %%
df3
# Out:
#    a  b
# 0  1  2
# 1  3  4

# %%
udemy=pd.read_csv('data/udemy_courses.csv')
udemy
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %%
udemy.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
udemy.head(1)
# Out:
#    course_id                        course_title  \
# 0    1070968  Ultimate Investment Banking Course
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
#
#    num_subscribers  num_reviews  num_lectures       level  content_duration  \
# 0             2147           23            51  All Levels               1.5
#
#     published_timestamp           subject
# 0  2017-01-18T20:58:58Z  Business Finance

# %%
udemy.tail()
# Out:
#       course_id                                       course_title  \
# 888     1083744  How to Invest Using ETFs from Former Wall Stre...
# 1014    1156530                   How to trade in the Forex market
# 1076     876898                          Forex - Help I cant Trade
# 1086    1029322                     Accounting and Business Basics
# 1484    1164832                                Formation Photoshop
#
#                                                     url  is_paid  price  \
# 888             https://www.udemy.com/etf-master-class/     True    200
# 1014                https://www.udemy.com/forex-market/     True    200
# 1076     https://www.udemy.com/forex-help-i-cant-trade/     True    200
# 1086  https://www.udemy.com/accounting-and-business-...     True    200
# 1484         https://www.udemy.com/formation-photoshop/     True    200
#
#       num_subscribers  num_reviews  num_lectures               level  \
# ...

# %%
udemy.describe()
# Out:
#           course_id        price  num_subscribers   num_reviews  num_lectures  \
# count  3.678000e+03  3678.000000      3678.000000   3678.000000   3678.000000
# mean   6.759720e+05    66.049483      3197.150625    156.259108     40.108755
# std    3.432732e+05    61.005755      9504.117010    935.452044     50.383346
# min    8.324000e+03     0.000000         0.000000      0.000000      0.000000
# 25%    4.076925e+05    20.000000       111.000000      4.000000     15.000000
# 50%    6.879170e+05    45.000000       911.500000     18.000000     25.000000
# 75%    9.613555e+05    95.000000      2546.000000     67.000000     45.750000
# max    1.282064e+06   200.000000    268923.000000  27445.000000    779.000000
#
#        content_duration
# count       3678.000000
# mean           4.094517
# std            6.053840
# min            0.000000
# 25%            1.000000
# 50%            2.000000
# 75%            4.500000
# max           78.500000

# %%
udemy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   object
#  11  subject              3678 non-null   object
# dtypes: bool(1), float64(1), int64(5), object(5)
# memory usage: 319.8+ KB

# %%
udemy.shape
# Out:
# (3678, 12)

# %%
udemy.shape[0]
# Out:
# 3678

# %%
udemy.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
udemy.index
# Out:
# Index([3230, 3232, 3204, 3247, 3254, 3246, 3251, 2827, 3228, 1979,
#        ...
#        1481, 1769,  408,  415,  638,  888, 1014, 1076, 1086, 1484],
#       dtype='int64', length=3678)

# %%
udemy.course_title
# Out:
# 0                      Ultimate Investment Banking Course
# 1       Complete GST Course & Certification - Grow You...
# 2       Financial Modeling for Business Analysts and C...
# 3       Beginner to Pro - Financial Analysis in Excel ...
# 4            How To Maximize Your Profits Trading Options
#                               ...
# 3673    Learn jQuery from Scratch - Master of JavaScri...
# 3674    How To Design A WordPress Website With No Codi...
# 3675                        Learn and Build using Polymer
# 3676    CSS Animations: Create Amazing Effects on Your...
# 3677    Using MODX CMS to Build Websites: A Beginner's...
# Name: course_title, Length: 3678, dtype: object

# %%
df1
# Out:
#     Name  Age     Place
# s1   anu   12     cochi
# s2  manu   13   calicut
# s3  sinu   14  banglure

# %%
df1.Age.min()
# Out:
# 12

# %%
df1.Age.idxmax()
# Out:
# 's3'

# %%
s= pd.Series(['anu','sinu','manu'])
s
# Out:
# 0     anu
# 1    sinu
# 2    manu
# dtype: object

# %%
s[2]
# Out:
# 'manu'

# %%
net = pd.read_csv("data/netflix_titles.csv")
net
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
net.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
net.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
net[['title','director']]
# Out:
#                       title         director
# 0      Dick Johnson Is Dead  Kirsten Johnson
# 1             Blood & Water              NaN
# 2                 Ganglands  Julien Leclercq
# 3     Jailbirds New Orleans              NaN
# 4              Kota Factory              NaN
# ...                     ...              ...
# 8802                 Zodiac    David Fincher
# 8803            Zombie Dumb              NaN
# 8804             Zombieland  Ruben Fleischer
# 8805                   Zoom     Peter Hewitt
# 8806                 Zubaan      Mozez Singh
#
# [8807 rows x 2 columns]

# %%
net[0:7]
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
net[0:7]['title']
# Out:
# 0                Dick Johnson Is Dead
# 1                       Blood & Water
# 2                           Ganglands
# 3               Jailbirds New Orleans
# 4                        Kota Factory
# 5                       Midnight Mass
# 6    My Little Pony: A New Generation
# Name: title, dtype: object

# %%
net.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
net[0:7][['title','type']]
# Out:
#                               title     type
# 0              Dick Johnson Is Dead    Movie
# 1                     Blood & Water  TV Show
# 2                         Ganglands  TV Show
# 3             Jailbirds New Orleans  TV Show
# 4                      Kota Factory  TV Show
# 5                     Midnight Mass  TV Show
# 6  My Little Pony: A New Generation    Movie

# %%
net.columns[4]
# Out:
# 'cast'

# %%
net[4]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 4
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
net.loc[4:5,'title':'rating']
# Out:
#            title       director  \
# 4   Kota Factory            NaN
# 5  Midnight Mass  Mike Flanagan
#
#                                                 cast country  \
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...   India
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...     NaN
#
#            date_added  release_year rating
# 4  September 24, 2021          2021  TV-MA
# 5  September 24, 2021          2021  TV-MA

# %%
net.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
net.set_index('show_id',inplace=True)

# %%
net
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb              NaN
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
net.loc['s4']
# Out:
# type                                                      TV Show
# title                                       Jailbirds New Orleans
# director                                                      NaN
# cast                                                          NaN
# country                                                       NaN
# date_added                                     September 24, 2021
# release_year                                                 2021
# rating                                                      TV-MA
# duration                                                 1 Season
# listed_in                                  Docuseries, Reality TV
# description     Feuds, flirtations and toilet talk go down amo...
# Name: s4, dtype: object

# %%
net.reset_index(inplace=True)
net
# Out:
#       index show_id     type                  title         director  \
# 0         0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         1      s2  TV Show          Blood & Water              NaN
# 2         2      s3  TV Show              Ganglands  Julien Leclercq
# 3         3      s4  TV Show  Jailbirds New Orleans              NaN
# 4         4      s5  TV Show           Kota Factory              NaN
# ...     ...     ...      ...                    ...              ...
# 8802   8802   s8803    Movie                 Zodiac    David Fincher
# 8803   8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# ...

# %%
df= pd.DataFrame({
    'a':[1,2,3,4,5,6,7],
    'b':[2,3,2,5,1,6,4],
    'c':[0,0,8,4,0,0,0]
})
df
# Out:
#    a  b  c
# 0  1  2  0
# 1  2  3  0
# 2  3  2  8
# 3  4  5  4
# 4  5  1  0
# 5  6  6  0
# 6  7  4  0

# %%
condition = df.loc[2]>2
condition
# Out:
# a     True
# b    False
# c     True
# Name: 2, dtype: bool

# %%
df.loc[:,condition]
# Out:
#    a  b  c
# 0  1  2  0
# 1  2  3  0
# 2  3  2  8
# 3  4  5  4
# 4  5  1  0
# 5  6  6  0
# 6  7  4  0

# %%
c=df.loc[:,'a']>1
c
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# Name: a, dtype: bool

# %%
df.loc[c,:]
# Out:
#    a  b  c
# 1  2  3  0
# 2  3  2  8
# 3  4  5  4
# 4  5  1  0
# 5  6  6  0
# 6  7  4  0

# %%
df.loc[lambda df:df['a']>4,:]
# Out:
#    a  b  c
# 4  5  1  0
# 5  6  6  0
# 6  7  4  0

# %%
net.iloc[4]
# Out:
# index                                                           4
# show_id                                                        s5
# type                                                      TV Show
# title                                                Kota Factory
# director                                                      NaN
# cast            Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# country                                                     India
# date_added                                     September 24, 2021
# release_year                                                 2021
# rating                                                      TV-MA
# duration                                                2 Seasons
# listed_in       International TV Shows, Romantic TV Shows, TV ...
# description     In a city of coaching centers known to train I...
# Name: 4, dtype: object

# %%
net.iloc[[4,5]]
# Out:
#    index show_id     type          title       director  \
# 4      4      s5  TV Show   Kota Factory            NaN
# 5      5      s6  TV Show  Midnight Mass  Mike Flanagan
#
#                                                 cast country  \
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...   India
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...     NaN
#
#            date_added  release_year rating   duration  \
# 4  September 24, 2021          2021  TV-MA  2 Seasons
# 5  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 4  International TV Shows, Romantic TV Shows, TV ...
# 5                 TV Dramas, TV Horror, TV Mysteries
#
#                                          description
# 4  In a city of coaching centers known to train I...
# 5  The arrival of a charismatic young priest brin...

# %%
net.iloc[[4,5],[4]]
# Out:
#         director
# 4            NaN
# 5  Mike Flanagan

# %%
net.iloc[4:7,[3,4,5]]
# Out:
#                               title                       director  \
# 4                      Kota Factory                            NaN
# 5                     Midnight Mass                  Mike Flanagan
# 6  My Little Pony: A New Generation  Robert Cullen, José Luis Ucha
#
#                                                 cast
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...
# 6  Vanessa Hudgens, Kimiko Glenn, James Marsden, ...

# %%
net.iloc[4:10,2:6]
# Out:
#       type                             title                       director  \
# 4  TV Show                      Kota Factory                            NaN
# 5  TV Show                     Midnight Mass                  Mike Flanagan
# 6    Movie  My Little Pony: A New Generation  Robert Cullen, José Luis Ucha
# 7    Movie                           Sankofa                   Haile Gerima
# 8  TV Show     The Great British Baking Show                Andy Devonshire
# 9    Movie                      The Starling                 Theodore Melfi
#
#                                                 cast
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...
# 6  Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9  Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...

# %%
net.iloc[4:20:2,2:10:2]
# Out:
#        type                                       director  \
# 4   TV Show                                            NaN
# 6     Movie                  Robert Cullen, José Luis Ucha
# 8   TV Show                                Andy Devonshire
# 10  TV Show                                            NaN
# 12    Movie                            Christian Schwochow
# 14  TV Show                                            NaN
# 16    Movie  Pedro de Echave García, Pablo Azorín Williams
# 18    Movie                                     Adam Salky
#
#                     country  release_year
# 4                     India          2021
# 6                       NaN          2021
# 8            United Kingdom          2021
# 10                      NaN          2021
# 12  Germany, Czech Republic          2021
# 14                      NaN          2021
# 16                      NaN          2020
# 18                      NaN          2021

# %%
net.columns
# Out:
# Index(['index', 'show_id', 'type', 'title', 'director', 'cast', 'country',
#        'date_added', 'release_year', 'rating', 'duration', 'listed_in',
#        'description'],
#       dtype='object')

# %%
df1
# Out:
#     Name  Age      City
# s1   anu   12     cochi
# s2  manu   13   calicut
# s3  sinu   14  banglure

# %%
df
# Out:
#    a  b  c
# 0  1  2  0
# 1  2  3  0
# 2  3  2  8
# 3  4  5  4
# 4  5  1  0
# 5  6  6  0
# 6  7  4  0

# %%
c = (df['a']<5) & (df['b']>1)
#boolean indexing used
df.iloc[list(c)]
# Out:
#    a  b  c
# 0  1  2  0
# 1  2  3  0
# 2  3  2  8
# 3  4  5  4

# %%
df.iloc[lambda df: list(c)]
# Out:
#    a  b  c
# 0  1  2  0
# 1  2  3  0
# 2  3  2  8
# 3  4  5  4

# %%
##filtering and sorting

# %%
titanic = pd.read_csv('data/tested.csv')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
cond = (titanic['Pclass']==3)
titanic.loc[cond,['Name', 'Age']]
# Out:
#                                              Name   Age
# 0                                Kelly, Mr. James  34.5
# 1                Wilkes, Mrs. James (Ellen Needs)  47.0
# 3                                Wirz, Mr. Albert  27.0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0
# 5                      Svensson, Mr. Johan Cervin  14.0
# ..                                            ...   ...
# 412                Henriksson, Miss. Jenny Lovisa  28.0
# 413                            Spector, Mr. Woolf   NaN
# 415                  Saether, Mr. Simon Sivertsen  38.5
# 416                           Ware, Mr. Frederick   NaN
# 417                      Peter, Master. Michael J   NaN
#
# [218 rows x 2 columns]

# %%
cond1= ((titanic['Sex']=='female') & (titanic['Age']>30))
titanic.loc[cond,'Name']
# Out:
# 0                                  Kelly, Mr. James
# 1                  Wilkes, Mrs. James (Ellen Needs)
# 3                                  Wirz, Mr. Albert
# 4      Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5                        Svensson, Mr. Johan Cervin
#                            ...
# 412                  Henriksson, Miss. Jenny Lovisa
# 413                              Spector, Mr. Woolf
# 415                    Saether, Mr. Simon Sivertsen
# 416                             Ware, Mr. Frederick
# 417                        Peter, Master. Michael J
# Name: Name, Length: 218, dtype: object

# %%
pd.set_option('display.max_rows',titanic.shape[0]+1)
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# 5            897         0       3
# 6            898         1       3
# 7            899         0       2
# 8            900         1       3
# 9            901         0       3
# 10           902         0       3
# 11           903         0       1
# 12           904         1       1
# 13           905         0       2
# 14           906         1       1
# 15           907         1       2
# 16           908         0       2
# 17           909         0       3
# 18           910         1       3
# 19           911         1       3
# 20           912         0       1
# 21           913         0       3
# 22           914         1       1
# 23           915         0       1
# 24           916         1       1
# ...

# %%
titanic.loc[cond,'Name']
# Out:
# 0                                       Kelly, Mr. James
# 1                       Wilkes, Mrs. James (Ellen Needs)
# 3                                       Wirz, Mr. Albert
# 4           Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5                             Svensson, Mr. Johan Cervin
# 6                                   Connolly, Miss. Kate
# 8              Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9                                Davies, Mr. John Samuel
# 10                                      Ilieff, Mr. Ylio
# 17                                     Assaf, Mr. Gerios
# 18                          Ilmakangas, Miss. Ida Livija
# 19                 Assaf Khalil, Mrs. Mariana (Miriam")"
# 21                             Olsen, Master. Artur Karl
# 25                               Robins, Mr. Alexander A
# 27                                     Daher, Mr. Shedid
# 29                                     Samaan, Mr. Elias
# ...

# %%
net  = pd.read_csv('data/netflix_titles.csv')
net
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
#isin
countries = ['India','United Kingdom']
condition = net['country'].isin(countries)
net[condition]
# Out:
#      show_id     type                          title                 director  \
# 4         s5  TV Show                   Kota Factory                      NaN
# 8         s9  TV Show  The Great British Baking Show          Andy Devonshire
# 24       s25    Movie                          Jeans               S. Shankar
# 32       s33  TV Show                  Sex Education                      NaN
# 39       s40  TV Show                   Chhota Bheem                      NaN
# ...      ...      ...                            ...                      ...
# 8775   s8776  TV Show                Yeh Meri Family                      NaN
# 8786   s8787    Movie                   You Can Tutu              James Brown
# 8798   s8799    Movie                       Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800    Movie                          Zenda           Avadhoot Gupte
# 8806   s8807    Movie                         Zubaan              Mozez Singh
#
# ...

# %%
net.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
mask3=net['cast'].str.contains('Jack Black',na =False)
net[mask3]
# Out:
#      show_id     type                                     title  \
# 172     s173    Movie                            School of Rock
# 573     s574    Movie                             Kung Fu Panda
# 574     s575    Movie                           Kung Fu Panda 2
# 1256   s1257    Movie        Tenacious D in The Pick of Destiny
# 3691   s3692  TV Show  DreamWorks Kung Fu Panda Awesome Secrets
# 5084   s5085    Movie                            The Polka King
# 5857   s5858    Movie      Kung Fu Panda: Secrets of the Scroll
# 6883   s6884    Movie           Goosebumps 2: Haunted Halloween
# 7241   s7242    Movie                    Kung Fu Panda: Holiday
# 7439   s7440    Movie                     Melvin Goes to Dinner
# 7553   s7554    Movie                               Nacho Libre
# 8263   s8264    Movie                               The D Train
#
#                           director  \
# 172              Richard Linklater
# 573   John Stevenson, Mark Osborne
# ...

# %%
udemy
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %%
udemy.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
udemy.sort_values(by='price')
# Out:
#       course_id                                       course_title  \
# 1369     874656   Create Stunning Infographics to Share your Ideas
# 433      199822      IAS 12 - Accounting for Income Taxes (Basics)
# 432      830870     Forex Trading For Beginners: Technical Trading
# 966      662996  The Tax Advantaged Investor: A Guide to Legal ...
# 3297     563668  Learn how to create a WordPress theme using Pi...
# ...         ...                                                ...
# 3233     446134  Ultimate Web Designer & Developer Course: Buil...
# 3232     764164              The Complete Web Developer Course 2.0
# 1136     645634  How to Build Profitable FOREX Automated Tradin...
# 888     1083744  How to Invest Using ETFs from Former Wall Stre...
# 0       1070968                 Ultimate Investment Banking Course
#
#                                                     url  is_paid  price  \
# 1369                 https://www.udemy.com/infographic/    False      0
# ...

# %%
udemy.sort_values(by=['num_reviews','price'],ascending=[False,True])
# Out:
#       course_id                                       course_title  \
# 3230     625204                         The Web Developer Bootcamp
# 3232     764164              The Complete Web Developer Course 2.0
# 3204     756150  Angular 4 (formerly Angular 2) - The Complete ...
# 3247     364426          JavaScript: Understanding the Weird Parts
# 3254     705264                            Modern React with Redux
# ...         ...                                                ...
# 888     1083744  How to Invest Using ETFs from Former Wall Stre...
# 1014    1156530                   How to trade in the Forex market
# 1076     876898                          Forex - Help I cant Trade
# 1086    1029322                     Accounting and Business Basics
# 1484    1164832                                Formation Photoshop
#
#                                                     url  is_paid  price  \
# 3230  https://www.udemy.com/the-web-developer-bootcamp/     True    200
# ...

# %%
udemy.sort_values(by=['num_reviews','price'],ascending=[False,True],inplace=True)

# %%
udemy['price'].sort_values()
# Out:
# 213       0
# 2689      0
# 827       0
# 179       0
# 1395      0
#        ...
# 2943    200
# 3404    200
# 75      200
# 2207    200
# 1484    200
# Name: price, Length: 3678, dtype: int64

# %%
udemy.sort_index()
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %%
udemy['num_reviews'].nlargest(10)
# Out:
# 3230    27445
# 3232    22412
# 3204    19649
# 3247    16976
# 3254    15117
# 3246    11580
# 3251    11123
# 2827     8629
# 3228     8341
# 1979     7676
# Name: num_reviews, dtype: int64

# %%
udemy['num_reviews'].nsmallest(10)
# Out:
# 213     0
# 878     0
# 1104    0
# 1108    0
# 1209    0
# 2350    0
# 2422    0
# 256     0
# 411     0
# 453     0
# Name: num_reviews, dtype: int64

# %%
udemy.nsmallest(10,'num_reviews')
# Out:
#       course_id                                       course_title  \
# 213     1266148  Preparation of Consolidated Financial Statemen...
# 878     1225194  Zoho Books Gestion Financière d'Entreprise pas...
# 1104    1024862  Making Tax Digital - UK HMRC Legislation Expla...
# 1108    1268616  Condor Broken Wing Butterfly Options Trading C...
# 1209    1261122                        画像加工の初心者でも「１日」で初歩を覚えられる無料講座
# 2350    1196538  Piano Building Blocks: Learn Chord Additions &...
# 2422     968026             Learn to Play Tabla - The Indian drums
# 256      831940     Fundamentals of Accounting for Business Owners
# 411      811534        The Visual Learning Basic Accounting Course
# 453      837322  Essentials of money value: Get a financial Life !
#
#                                                     url  is_paid  price  \
# 213   https://www.udemy.com/preparation-of-consolida...    False      0
# 878   https://www.udemy.com/zoho-books-gestion-finan...    False      0
# ...

# %%
udemy.nlargest(10,'num_reviews')
# Out:
#       course_id                                       course_title  \
# 3230     625204                         The Web Developer Bootcamp
# 3232     764164              The Complete Web Developer Course 2.0
# 3204     756150  Angular 4 (formerly Angular 2) - The Complete ...
# 3247     364426          JavaScript: Understanding the Weird Parts
# 3254     705264                            Modern React with Redux
# 3246     289230                     Learn and Understand AngularJS
# 3251     461160                        Learn and Understand NodeJS
# 2827      41295               Learn HTML5 Programming From Scratch
# 3228     719002  Angular 2 with TypeScript for Beginners: The P...
# 1979     238934  Pianoforall - Incredible New Way To Learn Pian...
#
#                                                     url  is_paid  price  \
# 3230  https://www.udemy.com/the-web-developer-bootcamp/     True    200
# 3232  https://www.udemy.com/the-complete-web-develop...     True    200
# ...

# %%
udemy['level']
# Out:
# 3230            All Levels
# 3232            All Levels
# 3204            All Levels
# 3247            All Levels
# 3254            All Levels
#                ...
# 888             All Levels
# 1014    Intermediate Level
# 1076            All Levels
# 1086            All Levels
# 1484        Beginner Level
# Name: level, Length: 3678, dtype: object

# %%
udemy['level'].value_counts()
# Out:
# level
# All Levels            1929
# Beginner Level        1270
# Intermediate Level     421
# Expert Level            58
# Name: count, dtype: int64

# %%
udemy['is_paid'].value_counts()
# Out:
# is_paid
# True     3368
# False     310
# Name: count, dtype: int64

# %%
udemy['subject']
# Out:
# 3230     Web Development
# 3232     Web Development
# 3204     Web Development
# 3247     Web Development
# 3254     Web Development
#               ...
# 888     Business Finance
# 1014    Business Finance
# 1076    Business Finance
# 1086    Business Finance
# 1484      Graphic Design
# Name: subject, Length: 3678, dtype: object

# %%
grp=udemy.groupby(['subject'])
grp

# %%
grp.describe()
# Out:
#                     course_id                                         \
#                         count           mean            std      min
# subject
# Business Finance       1195.0  643844.401674  347829.980907  19653.0
# Graphic Design          603.0  720273.257048  347586.461655  15467.0
# Musical Instruments     680.0  638648.450000  347230.455168  12214.0
# Web Development        1200.0  706854.250833  328924.399250   8324.0
#
#                                                                 price  \
#                           25%       50%        75%        max   count
# subject
# Business Finance     364688.0  629060.0   929336.0  1282064.0  1195.0
# Graphic Design       448499.0  733654.0  1023416.0  1276020.0   603.0
# Musical Instruments  338306.0  653397.0   917240.0  1272282.0   680.0
# Web Development      475711.5  738456.0   975271.5  1277924.0  1200.0
#
#                                 ... num_lectures        content_duration  \
# ...

# %%
grp.describe()
# Out:
#                     course_id                                         \
#                         count           mean            std      min
# subject
# Business Finance       1195.0  643844.401674  347829.980907  19653.0
# Graphic Design          603.0  720273.257048  347586.461655  15467.0
# Musical Instruments     680.0  638648.450000  347230.455168  12214.0
# Web Development        1200.0  706854.250833  328924.399250   8324.0
#
#                                                                 price  \
#                           25%       50%        75%        max   count
# subject
# Business Finance     364688.0  629060.0   929336.0  1282064.0  1195.0
# Graphic Design       448499.0  733654.0  1023416.0  1276020.0   603.0
# Musical Instruments  338306.0  653397.0   917240.0  1272282.0   680.0
# Web Development      475711.5  738456.0   975271.5  1277924.0  1200.0
#
#                                 ... num_lectures        content_duration  \
# ...

# %%
grp['price'].mean()
# Out:
# subject
# Business Finance       68.552301
# Graphic Design         57.827529
# Musical Instruments    49.558824
# Web Development        77.033333
# Name: price, dtype: float64

# %%
grp.get_group("Graphic Design")
# Out:
#       course_id                                       course_title  \
# 1211     874012  The Ultimate Drawing Course - Beginner to Adva...
# 1409     660876          Graphic Design - An Overview of the Field
# 1461     348116  Photoshop In-Depth: Master all of Photoshop's ...
# 1210     749542                            Graphic Design Bootcamp
# 1215     371074       Sketch 3 from A to Z: Become an App Designer
# ...         ...                                                ...
# 1385    1274846   Photoshop Avançado - Pós Produção e fusão com 3D
# 1624    1275872                    The Complete Adobe Spark Course
# 1481    1216164         Photoshop - Automatização com Adobe Script
# 1769    1240730                Architectural Drawing For Creatives
# 1484    1164832                                Formation Photoshop
#
#                                                     url  is_paid  price  \
# 1211  https://www.udemy.com/the-ultimate-drawing-cou...     True    150
# ...

# %%
grp['price'].mean()
# Out:
# subject
# Business Finance       68.552301
# Graphic Design         57.827529
# Musical Instruments    49.558824
# Web Development        77.033333
# Name: price, dtype: float64

# %%
grp['price'].max()
# Out:
# subject
# Business Finance       200
# Graphic Design         200
# Musical Instruments    200
# Web Development        200
# Name: price, dtype: int64

# %%
grp['price'].mean()['Web Development']
# Out:
# 77.03333333333333

# %%
grp['subject'].count()
# Out:
# subject
# Business Finance       1195
# Graphic Design          603
# Musical Instruments     680
# Web Development        1200
# Name: subject, dtype: int64

# %%
udemy['subject'].value_counts()
# Out:
# subject
# Web Development        1200
# Business Finance       1195
# Musical Instruments     680
# Graphic Design          603
# Name: count, dtype: int64

# %%
res= grp['num_subscribers'].agg([min,max])
res
# Out:
#                      min     max
# subject
# Business Finance       0   65576
# Graphic Design         0   53851
# Musical Instruments    0  101154
# Web Development       19  268923

# %%
udemy.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')
