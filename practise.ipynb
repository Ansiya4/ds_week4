# %%
import pandas as pd
import numpy as np

# %%
l1 = ['s1','s2','s3',12]
l2=['a','b','c','d']
se=pd.Series(l1,index=l2)
se
# Out:
# a    s1
# b    s2
# c    s3
# d    12
# dtype: object

# %%
se[2]
# Out:
# 's3'

# %%
mydata = {
    'name':['anu','minu','sinu'],
    'age':[12,13,14]
}
indx=[1,2,3]
new = pd.DataFrame(mydata,index =indx)
new
# Out:
#    name  age
# 1   anu   12
# 2  minu   13
# 3  sinu   14

# %%
new.columns
# Out:
# Index(['name', 'age'], dtype='object')

# %%
type(new)
# Out:
# pandas.core.frame.DataFrame

# %%
type(new.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
new['age']
# Out:
# 1    12
# 2    13
# 3    14
# Name: age, dtype: int64

# %%
dt=pd.read_csv('data/udemy_courses.csv')

# %%
dt.shape
# Out:
# (3678, 12)

# %%
dt.shape[0]
# Out:
# 3678

# %%
dt.shape[1]
# Out:
# 12

# %%
dt.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
dt.loc[3]
# Out:
# course_id                                                        1210588
# course_title           Beginner to Pro - Financial Analysis in Excel ...
# url                    https://www.udemy.com/complete-excel-finance-c...
# is_paid                                                             True
# price                                                                 95
# num_subscribers                                                     2451
# num_reviews                                                           11
# num_lectures                                                          36
# level                                                         All Levels
# content_duration                                                     3.0
# published_timestamp                                 2017-05-30T20:07:24Z
# subject                                                 Business Finance
# Name: 3, dtype: object

# %%
si= pd.Series(range(1,len(dt)+1))
dt.set_index([si,si**2])
# Out:
#                course_id                                       course_title  \
# 1    1           1070968                 Ultimate Investment Banking Course
# 2    4           1113822  Complete GST Course & Certification - Grow You...
# 3    9           1006314  Financial Modeling for Business Analysts and C...
# 4    16          1210588  Beginner to Pro - Financial Analysis in Excel ...
# 5    25          1011058       How To Maximize Your Profits Trading Options
# ...                  ...                                                ...
# 3674 13498276     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3675 13505625    1088178  How To Design A WordPress Website With No Codi...
# 3676 13512976     635248                      Learn and Build using Polymer
# 3677 13520329     905096  CSS Animations: Create Amazing Effects on Your...
# 3678 13527684     297602  Using MODX CMS to Build Websites: A Beginner's...
#
# ...

# %%
import pandas as pd
pd.options.display.max_rows=100
df=pd.read_csv('data/udemy_courses.csv')
print(df)
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   object
#  11  subject              3678 non-null   object
# dtypes: bool(1), float64(1), int64(5), object(5)
# memory usage: 319.8+ KB

# %%
dt['price']
# Out:
# 0       200
# 1        75
# 2        45
# 3        95
# 4       200
#        ...
# 3673    100
# 3674     25
# 3675     40
# 3676     50
# 3677     45
# Name: price, Length: 3678, dtype: int64

# %%
dt.set_index?
# Out:
# Signature:
# dt.set_index(
#     keys,
#     *,
#     drop: 'bool' = True,
#     append: 'bool' = False,
#     inplace: 'bool' = False,
#     verify_integrity: 'bool' = False,
# ) -> 'DataFrame | None'
# Docstring:
# Set the DataFrame index using existing columns.
#
# Set the DataFrame index (row labels) using one or more existing
# columns or arrays (of the correct length). The index can replace the
# existing index or expand on it.
#
# Parameters
# ----------
# keys : label or array-like or list of labels/arrays
#     This parameter can be either a single column key, a single array of
#     the same length as the calling DataFrame, or a list containing an
#     arbitrary combination of column keys and arrays. Here, "array"
#     encompasses :class:`Series`, :class:`Index`, ``np.ndarray``, and
#     instances of :class:`~collections.abc.Iterator`.
# drop : bool, default True
#     Delete columns to be used as the new index.
# append : bool, default False
# ...

# %%
dt.iloc[4:8,1:6]
# Out:
#                                         course_title  \
# 4       How To Maximize Your Profits Trading Options
# 5  Trading Penny Stocks: A Guide for All Levels I...
# 6  Investing And Trading For Beginners: Mastering...
# 7  Trading Stock Chart Patterns For Immediate, Ex...
#
#                                                  url  is_paid  price  \
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
# 5  https://www.udemy.com/trading-penny-stocks-a-g...     True    150
# 6  https://www.udemy.com/investing-and-trading-fo...     True     65
# 7  https://www.udemy.com/trading-chart-patterns-f...     True     95
#
#    num_subscribers
# 4             1276
# 5             9221
# 6             1540
# 7             2917

# %%
pd.set_option('display.max_rows',dt.shape[0]+1)
dt
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# 5        192870  Trading Penny Stocks: A Guide for All Levels I...
# 6        739964  Investing And Trading For Beginners: Mastering...
# 7        403100  Trading Stock Chart Patterns For Immediate, Ex...
# 8        476268  Options Trading 3 : Advanced Stock Profit and ...
# 9       1167710  The Only Investment Strategy You Need For Your...
# 10       592338  Forex Trading Secrets of the Pros With Amazon'...
# 11       975046                    Trading Options With Money Flow
# 12       742602  Financial Management Risk and Return For Secur...
# ...

# %%
import pandas as pd
li = [['anu',12],['manu',],['sinu',14],['minu',]]
df = pd.DataFrame(li, index=[1,2,3,4], columns=['name', 'age'])
df['marks']=[100,200,150,100]
df
# Out:
#    name   age  marks
# 1   anu  12.0    100
# 2  manu   NaN    200
# 3  sinu  14.0    150
# 4  minu   NaN    100

# %%
df['age'].mean()
df.fillna(df['age'].mean(),inplace= True)

# %%
df.rename(columns={'name': 'fname'}, inplace=True)

df.columns
# Out:
# Index(['fname', 'age', 'marks', 'lname'], dtype='object')

# %%
df['lname']=['a','','r','h']
df.columns=['fname', 'age', 'marks','lname']

# %%
df=df[['fname','lname', 'age', 'marks']]

# %%
df
# Out:
#   fname lname   age  marks
# 1   anu     a  12.0    100
# 2  manu        13.0    200
# 3  sinu     r  14.0    150
# 4  minu     h  13.0    100

# %%
df.dropna()
# Out:
#   fname lname   age  marks
# 1   anu     a  12.0    100
# 2  manu        13.0    200
# 3  sinu     r  14.0    150
# 4  minu     h  13.0    100

# %%
import numpy as np

# %%
arr=np.identity((3))

# %%
arr
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
import pandas as pd
df = pd.read_csv('data/student_scores.csv')

# %%
df.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
df.plot.scatter(x='Hours',y='Scores',title= "scatterplot")
# Out:
# <Axes: title={'center': 'scatterplot'}, xlabel='Hours', ylabel='Scores'>

# %%
a=[2,3,4,5]
b=[4,5,6,7]
import matplotlib.pyplot as plt
plt.plot(a,b,color='red');

# %%
iris = pd.read_csv('data/netflix_titles.csv')

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB
